# %% [markdown]
# # Classification II –   Homework
#
# **Overview**
# - [Large Movie Review Dataset](http://ai.stanford.edu/~amaas/data/sentiment/)
# - Target –   pos/neg folders
#
# **Evaluation Criteria** (max score - 8):
# * Text preprocessing - 3
#     – Removing stop words
#     - Stemming / Lemmatization
#     - Bag of words / TF-IDF
#     - N-grams
# * Words importance - 2
# * Hyperparameters tuning – 1
# * Compare performance of models: SGDClassifier; SVM; Naive Bayes - 2
# * Metric: AUC-ROC
# * Libraries: scikit‑learn  + NLTK

# %%
import os
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from bs4 import BeautifulSoup

from nltk.corpus import stopwords
from nltk.stem.snowball import EnglishStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

from sklearn.calibration import CalibratedClassifierCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

warnings.filterwarnings("ignore")
sns.set()
# %matplotlib inline

# %% [markdown]
# ### Loading the data
#
# First, let's load the dataset. Train/test splitting is already done and we will not change it. Also this dataset has perfect positive/negative class balance.

# %%
DATASET_DIR = 'D:/datasets/aclImdb'

def load_data(dir_name):
    X, y = [], []
    for sub_dir, target in (('pos', 1), ('neg', 0)):
        files = os.listdir(os.path.join(dir_name, sub_dir))
        X += [open(os.path.join(dir_name, sub_dir, fname),
                   encoding="utf-8"
                  ).read() for fname in files]
        y += [target] * len(files)
    return X, np.array(y)

txt_train, y_train = load_data(os.path.join(DATASET_DIR, 'train'))
txt_test, y_test = load_data(os.path.join(DATASET_DIR, 'test'))

print('Train set size: %i (%.0f%% positive)' %
      (len(y_train), np.sum(y_train) * 100 / len(y_train)))
print('Test set size: %i (%.0f%% positive)' %
      (len(y_test), np.sum(y_test) * 100 / len(y_test)))
# Out:
# Train set size: 25000 (50% positive)
# Test set size: 25000 (50% positive)

# %% [markdown]
# Now let's write some utility code for later use.

# %%
def show_scores(model, X_train, X_test, y_train, y_test):
    """
    Evaluate given model on train/test sets and display accuracy/ROCAUC scores.

    """
    y_train_scores = model.predict_proba(X_train)[:,1]
    y_test_scores = model.predict_proba(X_test)[:,1]
    y_train_pred = y_train_scores >= 0.5
    y_test_pred = y_test_scores >= 0.5
    print("Train set: ROCAUC = {0:.6f}, accuracy = {1:.6f}".format(
        roc_auc_score(y_train, y_train_scores), accuracy_score(y_train, y_train_pred)
    ))
    print("Test set: ROCAUC = {0:.6f}, accuracy = {1:.6f}".format(
        roc_auc_score(y_test, y_test_scores), accuracy_score(y_test, y_test_pred)
    ))

# %%
def print_feature_summary(vectorizer, txt_array):
    """
    Show example features generated by a vectorizer.
    
    """
    feature_names = np.array(vectorizer.get_feature_names())
    X = vectorizer.transform(txt_array)
    sums = np.array(X.sum(axis=0))[0]
    sorted_idx = sums.argsort()

    print('Total features:', len(feature_names))
    print("First 20 features:\n{}".format(feature_names[:20]))
    print("Features with highest count: \n{}".format(
        feature_names[sorted_idx[-20:]]))
    print("Features with lowest count:\n{}".format(
        feature_names[sorted_idx[:20]]))

# %% [markdown]
# We will train several models and add them all to this dictionary (for later comparison):

# %%
models = {}    # models will be stored here

# %% [markdown]
# ### Baseline model
#
# Let's start by mindlessly applying `CountVectorizer` and Multinomial Naive Bayes to our data:

# %%
pipe = Pipeline(steps=[
    ('bag', CountVectorizer()),
    ('nb', MultinomialNB())
])
pipe.fit(txt_train, y_train)
show_scores(pipe, txt_train, txt_test, y_train, y_test)
models['Naive Bayes (baseline)'] = pipe
# Out:
# Train set: ROCAUC = 0.962436, accuracy = 0.898120
# Test set: ROCAUC = 0.891853, accuracy = 0.813560

# %% [markdown]
# Not bad for a start, but we observe substantial overfitting. Let's take a look at generated features:

# %%
print_feature_summary(pipe.named_steps['bag'], txt_train)
# Out:
# Total features: 74849
# First 20 features:
# ['00' '000' '0000000000001' '00001' '00015' '000s' '001' '003830' '006'
#  '007' '0079' '0080' '0083' '0093638' '00am' '00pm' '00s' '01' '01pm' '02']
# Features with highest count:
# ['not' 'on' 'you' 'film' 'but' 'movie' 'with' 'for' 'as' 'was' 'that'
#  'this' 'in' 'it' 'br' 'is' 'to' 'of' 'and' 'the']
# Features with lowest count:
# ['lacing' 'lhakpa' 'liaised' 'liana' 'liason' 'libber' 'libed' 'libels'
#  'liberates' 'liberator' 'liberatore' 'liberia' 'libertini' 'libidinous'
#  'libra' 'librarianship' 'lha' 'lh' 'lgbt' 'león']

# %% [markdown]
# We see a lot of garbage features, numbers, standard and domain-specific stop words, HTML tags and so on. We will deal with them in the next section.

# %% [markdown]
# ### Vectorization tuning
#
# Things we do here:
# - Strip HTML tags (see `preprocessor`)
# - Use `RegexTokenizer` to split text into words (excluding all numbers)
# - Filter stop words. Also we extend stop word list with domain-specific stopwords 'movie' and 'film' as they are highly unlikely to help in sentiment analysis. Excluding them will significantly reduce the number of bigram features.
# - Snowball stemming and simple context-agnostic noun lemmatization (best strategy will be chosen via cross-validation)
# - Cutting off features below specified document frequency (`min_df` parameter)
# - Apply bigrams

# %%
stop_words = stopwords.words('english') + ['movie', 'film']
tokenizer = RegexpTokenizer(r"(?u)\b[^\W\d][^\W\d]+\b")
stemmer = EnglishStemmer()
lemmer = WordNetLemmatizer()

def preprocessor(text):
    """ Strip HTML tags and convert to lowercase. """
    return BeautifulSoup(text).get_text().lower()

def stemmed_words(doc):
    """ Split to tokens, ignore stopwords, apply stemming. """
    return [
        stemmer.stem(word)
        for word in tokenizer.tokenize(doc)
        if word not in stop_words
    ]

def lemmed_words(doc):
    """ Split to tokens, ignore stopwords, apply lemmatization. """
    return [
        lemmer.lemmatize(word)
        for word in tokenizer.tokenize(doc)
        if word not in stop_words
    ]

# %% [markdown]
# The best vectorization parameters will be found using cross-validation. This process is a bit involving and requiring multiple iterative steps as the number of possible combinations is very large. To keep this notebook clean and re-runnable we will only provide code for stemmer/lemmer choice and checking effectiveness of bigrams. The code to find the rest of the parameters is omitted.

# %%
pipe = Pipeline(steps=[
    ('bag', CountVectorizer(preprocessor=preprocessor, min_df=50)),
    ('nb', MultinomialNB())
])
params = {
    'bag__tokenizer': [stemmed_words, lemmed_words],
    'bag__ngram_range': [(1, 1), (1, 2)],
}
grid = GridSearchCV(pipe, params, cv=2, scoring='roc_auc', n_jobs=7)
grid.fit(txt_train, y_train)

show_scores(grid, txt_train, txt_test, y_train, y_test)
print("Best parameters:", grid.best_params_)
# Out:
# Train set: ROCAUC = 0.935962, accuracy = 0.872240
# Test set: ROCAUC = 0.918698, accuracy = 0.852040
# Best parameters: {'bag__ngram_range': (1, 2), 'bag__tokenizer': <function lemmed_words at 0x000001F36936C620>}

# %% [markdown]
# Lemmed bigrams win this battle. Also we have reduced overfitting to some extent and decreased the number of features by a factor of 10. Let's take a look at new features:

# %%
print_feature_summary(grid.best_estimator_.named_steps['bag'], txt_train)
# Out:
# Total features: 7594
# First 20 features:
# ['abandon' 'abandoned' 'abc' 'ability' 'able' 'able get' 'able see'
#  'abound' 'abraham' 'abrupt' 'abruptly' 'absence' 'absent' 'absolute'
#  'absolutely' 'absolutely loved' 'absolutely nothing' 'absorbed'
#  'absorbing' 'absurd']
# Features with highest count:
# ['first' 'great' 'also' 'bad' 'people' 'much' 'scene' 'well' 'really'
#  'see' 'make' 'would' 'get' 'even' 'story' 'character' 'good' 'time'
#  'like' 'one']
# Features with lowest count:
# ['realistically' 'another woman' 'much love' 'intensely' 'man woman'
#  'think really' 'thought great' 'almost everything' 'character play'
#  'rambling' 'find hard' 'way end' 'one woman' 'order get' 'last one'
#  'possibly worst' 'u believe' 'plodding' 'kept thinking' 'people one']

# %% [markdown]
# Much better looking, most of the garbage is gone.
#
# We used Naive Bayes as a reference model for this search. We will assume the same vectorization parameters will be optimal for other models as well. It is a disputable assumption indeed but let's stick to it to avoid really exhaustive grid search.
#
# So our final parameters for `CountVectorizer` are:

# %%
vectorizer_kwargs = {
    'preprocessor': preprocessor,
    'tokenizer': lemmed_words,
    'min_df': 50,
    'ngram_range': (1, 2),
}

# %% [markdown]
# ### Naive Bayes
#
# Now let's tune Multinomial Naive Bayes model itself by adjusting additive smoothing parameter `alpha`.

# %%
pipe = Pipeline(steps=[
    ('bag', CountVectorizer(**vectorizer_kwargs)),
    ('nb', MultinomialNB()),
])
params = {
    'nb__alpha': [0.5, 0.75, 1],
}
grid = GridSearchCV(pipe, params, cv=3, scoring='roc_auc', n_jobs=7)
grid.fit(txt_train, y_train)
models['Naive Bayes'] = grid.best_estimator_

show_scores(grid, txt_train, txt_test, y_train, y_test)
print("Best parameters:", grid.best_params_)
# Out:
# Train set: ROCAUC = 0.935962, accuracy = 0.872240
# Test set: ROCAUC = 0.918698, accuracy = 0.852040
# Best parameters: {'nb__alpha': 1}

# %% [markdown]
# Default setting was found to be optimal.
#
# Now let's take a look at the most descriptive features (one with highest empirical probability for positive/negative classes):

# %%
def show_bayes_word_importance(model):
    feature_names = model.named_steps['bag'].get_feature_names()
    pos_feats = zip(model.named_steps['nb'].feature_log_prob_[0], feature_names)
    neg_feats = zip(model.named_steps['nb'].feature_log_prob_[1], feature_names)
    pos_feats_sorted = [x[1] for x in sorted(pos_feats, key=lambda x: x[0])]
    neg_feats_sorted = [x[1] for x in sorted(neg_feats, key=lambda x: x[0])]
    print('Top positive features:\n', pos_feats_sorted[:20], '\n')
    print('Top negative features:\n', neg_feats_sorted[:20])
    
show_bayes_word_importance(models['Naive Bayes'])
# Out:
# Top positive features:
#  ['excellently', 'still great', 'delightfully', 'favorite movie', 'perfectly cast', 'walter matthau', 'absolutely loved', 'acting superb', 'best role', 'excellent job', 'wonderful performance', 'deliciously', 'ensemble cast', 'expertly', 'favorite character', 'heart warming', 'thoroughly enjoyed', 'another great', 'english subtitle', 'enjoyed much']
#
# Top negative features:
#  ['acting horrible', 'avoid like', 'acting awful', 'badly written', 'boll', 'even worth', 'possibly worst', 'skip one', 'total waste', 'uwe', 'uwe boll', 'worst acting', 'worst film', 'avoid cost', 'poorly made', 'seen bad', 'acting poor', 'complete waste', 'dreck', 'far worst']

# %% [markdown]
# Hilarious! This is exactly how it is supposed to be. Our model seems to rely on typical bigram "catchphrases" for good and bad sentiment.
#
# Now we proceed with other models. We will try logistic regression with/without TF-IDF and SVM. See conclusions in the corresponding section.

# %% [markdown]
# ### SGD (logistic regression, L2-regularization)

# %%
pipe = Pipeline(steps=[
    ('bag', CountVectorizer(**vectorizer_kwargs)),
    ('lin', SGDClassifier(loss='log', penalty='l2')),
])
params = {
    'lin__alpha': [1e-4, 1e-3, 1e-2],
}
grid = GridSearchCV(pipe, params, cv=4, scoring='roc_auc', n_jobs=7)
grid.fit(txt_train, y_train)
models['SGD Logistic regression'] = grid.best_estimator_

show_scores(grid, txt_train, txt_test, y_train, y_test)
print("Best parameters:", grid.best_params_)
# Out:
# Train set: ROCAUC = 0.957219, accuracy = 0.892720
# Test set: ROCAUC = 0.942396, accuracy = 0.871680
# Best parameters: {'lin__alpha': 0.01}

# %%
def show_linear_word_importance(model):
    feature_names = model.named_steps['bag'].get_feature_names()
    feats = list(zip(model.named_steps['lin'].coef_[0], feature_names))
    pos_feats = [x for x in feats if x[0] > 0]
    neg_feats = [x for x in feats if x[0] < 0]
    pos_feats_sorted = [x[1] for x in sorted(pos_feats, key=lambda x: x[0], reverse=True)]
    neg_feats_sorted = [x[1] for x in sorted(neg_feats, key=lambda x: x[0])]
    print('Top positive features:\n', pos_feats_sorted[:20], '\n')
    print('Top negative features:\n', neg_feats_sorted[:20])
    
show_linear_word_importance(models['SGD Logistic regression'])
# Out:
# Top positive features:
#  ['excellent', 'great', 'perfect', 'wonderful', 'favorite', 'amazing', 'loved', 'best', 'fun', 'today', 'one best', 'brilliant', 'highly', 'enjoyed', 'beautiful', 'superb', 'definitely', 'enjoy', 'fantastic', 'enjoyable']
#
# Top negative features:
#  ['worst', 'awful', 'waste', 'bad', 'boring', 'poor', 'terrible', 'worse', 'nothing', 'horrible', 'dull', 'unfortunately', 'stupid', 'poorly', 'annoying', 'save', 'supposed', 'waste time', 'instead', 'avoid']

# %% [markdown]
# ### SGD (logistic regression, L2-regularization) with TF-IDF

# %%
pipe = Pipeline(steps=[
    ('bag', CountVectorizer(**vectorizer_kwargs)),
    ('tfidf', TfidfTransformer()),
    ('lin', SGDClassifier(loss='log', penalty='l2')),
])
params = {
    'lin__alpha': [1e-4, 1e-3, 1e-2],
}
grid = GridSearchCV(pipe, params, cv=4, scoring='roc_auc', n_jobs=7)
grid.fit(txt_train, y_train)
models['SGD Logistic regression with TF-IDF'] = grid.best_estimator_

show_scores(grid, txt_train, txt_test, y_train, y_test)
print("Best parameters:", grid.best_params_)
# Out:
# Train set: ROCAUC = 0.967428, accuracy = 0.906000
# Test set: ROCAUC = 0.951838, accuracy = 0.881480
# Best parameters: {'lin__alpha': 0.0001}

# %%
show_linear_word_importance(models['SGD Logistic regression with TF-IDF'])
# Out:
# Top positive features:
#  ['great', 'excellent', 'best', 'wonderful', 'perfect', 'amazing', 'favorite', 'well', 'love', 'loved', 'fun', 'brilliant', 'enjoyed', 'today', 'one best', 'also', 'beautiful', 'superb', 'highly', 'life']
#
# Top negative features:
#  ['worst', 'bad', 'awful', 'waste', 'boring', 'poor', 'nothing', 'terrible', 'worse', 'horrible', 'dull', 'unfortunately', 'even', 'poorly', 'stupid', 'script', 'supposed', 'minute', 'annoying', 'ridiculous']

# %% [markdown]
# ### Linear SVM (with TF-IDF)
#
# Things to mention here:
# - We use linear SVM as kernelized versions do not scale well with thousands of features and sparse data
# - To complete ROCAUC score we need class probabilities which `LinearSVC` does not provide. That is, we need to apply probability calibration. Unfortunately `CalibratedClassifierCV` class does not interact properly with `Pipeline` and `GridSearchCV` so we will have to do some dirty workarounds

# %%
vect = Pipeline(steps=[
    ('bag', CountVectorizer(**vectorizer_kwargs)),
    ('tfidf', TfidfTransformer(norm='l2')),
])

vect.fit(txt_train)
X_train = vect.transform(txt_train)
X_test = vect.transform(txt_test)

params = {
    'C': [0.01, 0.1, 1],
}
grid = GridSearchCV(LinearSVC(), params, cv=3, scoring='roc_auc', n_jobs=7)
grid.fit(X_train, y_train)
clf = CalibratedClassifierCV(grid.best_estimator_, cv='prefit', method='isotonic')
clf.fit(X_train, y_train)

show_scores(clf, X_train, X_test, y_train, y_test)
print("Best parameters:", grid.best_params_)

models['Linear SVM with TF-IDF'] = clf
# Out:
# Train set: ROCAUC = 0.977509, accuracy = 0.923960
# Test set: ROCAUC = 0.954238, accuracy = 0.885520
# Best parameters: {'C': 0.1}

# %% [markdown]
# ### Summary and comparison
#
# First let's provide quality summary for all models:

# %%
def plot_roc_curves(models):
    """ Show ROC curves for all models on a single plot."""
    plt.figure(figsize = (8, 8))
    plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
    
    for name, model in models.items():
        
        if type(model) is CalibratedClassifierCV:
            y_test_scores = model.predict_proba(X_test)[:,1]
        else:
            y_test_scores = model.predict_proba(txt_test)[:,1]
            
        y_test_pred = y_test_scores >= 0.5

        acc = accuracy_score(y_test, y_test_pred)
        fpr, tpr, _ = roc_curve(y_test, y_test_scores)
        roc_auc = auc(fpr, tpr)
        
        label='%s (AUC = %0.4f, accuracy = %0.4f)' %  (name, roc_auc, acc)
        plt.plot(fpr, tpr, lw=2, label=label)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curves (on test set)', fontsize=16, fontweight='bold')
    plt.legend(loc="lower right")
    plt.show()

plot_roc_curves(models)

# %% [markdown]
# **Conclusion**:
# - Linear SVM and logistic regression perform slightly better than Naive Bayes here (though all scores are quite close)
# - TF-IDF does not give significant quality improvement. This is something we could expect because the sentiment is unlikely to be dominated by document-specific words. Sometimes applying TF-IDF it can even make things worse (especially for smaller values of `min_df`, thus the code to prove this is not provided in this notebook).
# - Naive Bayes relies heavily on bigram catchphrases while the other models do not. Coincidence? Not likely. Though this is hard to interpret but most likely it has something to do with the Naive Bayes' assumption of feature independence.
#
# **Room for improvement**:
# - account for negation in tokenization (process`not`, `don't`, etc)
# - advanced stemming or context-based lemmatization
# - resplit into train/test sets (thus getting more training data)
# - trying kernelized versions of SVM (though they might take an eternity to train)
#
# However, these measures are unlikely to push the prediction beyond the limitations of bag-of-words model.
